# %%
import numpy as np
import pandas as pd
from joblib import load
from processed_feature_mapping import mapping
from train_model import data_cleaning
from model_monitoring import ModelMonitoring

# %%
# 1a. Output the required cleaned data for train dataset
# Required processed data is already done in train_model.py
train_df = pd.read_csv('../data/raw_split_data/employee_train.csv')
train_df = data_cleaning(train_df)
X_train = train_df.drop(columns=['Attrition'])

column_transformer = load('./preprocessor/column_transformer.pkl')
label_encoder = load('./preprocessor/label_encoder.pkl')
RF_clf = load('./model/RF_clf.joblib')

y_train = train_df['Attrition']
X_train_processed = column_transformer.transform(X_train)
y_train_pred = RF_clf.predict(X_train_processed)
y_train_pred_inverse = label_encoder.inverse_transform(y_train_pred)
train_df['prediction'] = y_train_pred_inverse
train_df.rename(columns={'Attrition' : 'target'}, inplace=True)
train_df.to_csv('../data/cleaned_employee_train.csv', index=False)

# 1b. Output the required cleaned/processed data for test dataset
test_df = pd.read_csv("../data/raw_split_data/employee_test.csv")
test_df = data_cleaning(test_df)
X_test = test_df.drop(columns=['Attrition'])
y_test = test_df['Attrition']
X_test_processed = column_transformer.transform(X_test)
X_test_processed = pd.DataFrame.from_records(X_test_processed)
X_test_processed = mapping(X_test_processed, column_transformer)
X_test_processed.to_csv('../data/X_test_processed.csv', index=False)
y_test_pred = RF_clf.predict(X_test_processed)
y_test_pred_inverse = label_encoder.inverse_transform(y_test_pred)
y_test_pred_prob = RF_clf.predict_proba(X_test_processed)[:1]
test_df['prediction'] = y_test_pred_inverse
test_df.rename(columns={'Attrition' : 'target'}, inplace=True)
test_df.to_csv('../data/cleaned_employee_test.csv', index=False)

# %%
# With the required datasets out, firstly, we create the instance of the ModelMonitoring object 
model_monitoring = ModelMonitoring(train_df)

# %%
# But first, we check for the data types
model_monitoring.check_data_types(train_df, test_df)
# Out:
# The data types for all columns from both datasets are the same

# %%
# next we replace any ' ' in the column names with '_' for test_df
# it is not done for train_df because this should have already been handled 
# before the model is even being trained for the first time
model_monitoring.replace_column_names(test_df)

# %%
# then check to make sure that the column names of both datasets tally
model_monitoring.check_schema(train_df, test_df)
# Out:
# train and test dataset have the same features
# 1

# %%
# next we check for bad data i.e. cells that are by right empty but are filled with '?' and '-'
# and replace them with np.nan
model_monitoring.handle_bad_data(test_df)
# Out:
#      Age target  BusinessTravel  DailyRate              Department  \
# 0     36     No               2        429  Research & Development
# 1     36     No               3       1302  Research & Development
# 2     37     No               2        309                   Sales
# 3     41     No               2       1283  Research & Development
# 4     43     No               2        244         Human Resources
# ..   ...    ...             ...        ...                     ...
# 730   34     No               2        943  Research & Development
# 731   38     No               2       1084  Research & Development
# 732   27    Yes               2        135  Research & Development
# 733   45     No               1       1238  Research & Development
# 734   36     No               3        635  Research & Development
#
#      DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 0                   2          4     Life Sciences                        3
# 1                   6          4     Life Sciences                        1
# 2                  10          4     Life Sciences                        4
# 3                   5          5           Medical                        2
# 4                   2          3     Life Sciences                        2
# ..                ...        ...               ...                      ...
# 730                 9          3     Life Sciences                        4
# 731                29          3  Technical Degree                        4
# 732                17          4     Life Sciences                        4
# 733                 1          1     Life Sciences                        3
# 734                18          1           Medical                        2
#
#      Gender  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0    Female  ...                         4                 0
# 1      Male  ...                         4                 1
# 2    Female  ...                         3                 3
# 3      Male  ...                         1                 0
# 4      Male  ...                         2                 0
# ..      ...  ...                       ...               ...
# 730    Male  ...                         4                 1
# 731    Male  ...                         1                 1
# 732  Female  ...                         4                 0
# 733    Male  ...                         4                 1
# 734  Female  ...                         1                 0
#
#      TotalWorkingYears TrainingTimesLastYear  WorkLifeBalance YearsAtCompany  \
# 0                   18                     2                3             16
# 1                    9                     3                3              3
# 2                    8                     5                3              1
# 3                    7                     5                2              4
# 4                   10                     5                3              9
# ..                 ...                   ...              ...            ...
# 730                 10                     0                2              9
# 731                  9                     3                1              7
# 732                  8                     2                3              8
# 733                 25                     3                2             23
# 734                  8                     2                3              8
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                    14                        5                    12
# 1                     2                        0                     2
# 2                     0                        0                     0
# 3                     2                        0                     3
# 4                     7                        1                     8
# ..                  ...                      ...                   ...
# 730                   7                        1                     6
# 731                   7                        1                     7
# 732                   2                        7                     7
# 733                  15                       14                     4
# 734                   1                        1                     7
#
#     prediction
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No
# ..         ...
# 730         No
# 731         No
# 732        Yes
# 733         No
# 734         No
#
# [735 rows x 32 columns]

# %%
# after cleaning up the incoming data, using evidentlyai, we get a json/html file
# to visualize and get more insights about the data
data_quality_dict = model_monitoring.data_quality_report(train_df.drop(columns=['target', 'prediction']),
                                     test_df.drop(columns=['target', 'prediction']),
                                     'json')
data_quality_dict
# Out:
# {'metrics': [{'metric': 'DatasetSummaryMetric',
#    'result': {'almost_duplicated_threshold': 0.95,
#     'current': {'target': None,
#      'prediction': None,
#      'date_column': None,
#      'id_column': None,
#      'number_of_columns': 30,
#      'number_of_rows': 735,
#      'number_of_missing_values': 0,
#      'number_of_categorical_columns': 6,
#      'number_of_numeric_columns': 24,
#      'number_of_text_columns': 0,
#      'number_of_datetime_columns': 0,
#      'number_of_constant_columns': 0,
#      'number_of_almost_constant_columns': 0,
#      'number_of_duplicated_columns': 0,
#      'number_of_almost_duplicated_columns': 0,
#      'number_of_empty_rows': 0,
#      'number_of_empty_columns': 0,
#      'number_of_duplicated_rows': 0,
#      'nans_by_columns': {'Age': 0,
#       'BusinessTravel': 0,
#       'DailyRate': 0,
#       'Department': 0,
#       'DistanceFromHome': 0,
#       'Education': 0,
#       'EducationField': 0,
#       'EnvironmentSatisfaction': 0,
#       'Gender': 0,
#       'HourlyRate': 0,
#       'JobInvolvement': 0,
#       'JobLevel': 0,
#       'JobRole': 0,
#       'JobSatisfaction': 0,
#       'MaritalStatus': 0,
#       'MonthlyIncome': 0,
#       'MonthlyRate': 0,
#       'NumCompaniesWorked': 0,
#       'OverTime': 0,
#       'PercentSalaryHike': 0,
#       'PerformanceRating': 0,
#       'RelationshipSatisfaction': 0,
#       'StockOptionLevel': 0,
#       'TotalWorkingYears': 0,
#       'TrainingTimesLastYear': 0,
#       'WorkLifeBalance': 0,
#       'YearsAtCompany': 0,
#       'YearsInCurrentRole': 0,
#       'YearsSinceLastPromotion': 0,
#       'YearsWithCurrManager': 0},
#      'number_uniques_by_columns': {'Age': 42,
#       'BusinessTravel': 3,
#       'DailyRate': 556,
#       'Department': 3,
#       'DistanceFromHome': 29,
#       'Education': 5,
#       'EducationField': 6,
#       'EnvironmentSatisfaction': 4,
#       'Gender': 2,
#       'HourlyRate': 71,
#       'JobInvolvement': 4,
#       'JobLevel': 5,
#       'JobRole': 9,
#       'JobSatisfaction': 4,
#       'MaritalStatus': 3,
#       'MonthlyIncome': 706,
#       'MonthlyRate': 722,
#       'NumCompaniesWorked': 10,
#       'OverTime': 2,
#       'PercentSalaryHike': 15,
#       'PerformanceRating': 2,
#       'RelationshipSatisfaction': 4,
#       'StockOptionLevel': 4,
#       'TotalWorkingYears': 39,
#       'TrainingTimesLastYear': 7,
#       'WorkLifeBalance': 4,
#       'YearsAtCompany': 34,
#       'YearsInCurrentRole': 19,
#       'YearsSinceLastPromotion': 16,
#       'YearsWithCurrManager': 18}},
#     'reference': {'target': None,
#      'prediction': None,
#      'date_column': None,
#      'id_column': None,
#      'number_of_columns': 30,
#      'number_of_rows': 735,
#      'number_of_missing_values': 0,
#      'number_of_categorical_columns': 6,
#      'number_of_numeric_columns': 24,
#      'number_of_text_columns': 0,
#      'number_of_datetime_columns': 0,
#      'number_of_constant_columns': 0,
#      'number_of_almost_constant_columns': 0,
#      'number_of_duplicated_columns': 0,
#      'number_of_almost_duplicated_columns': 0,
#      'number_of_empty_rows': 0,
#      'number_of_empty_columns': 0,
#      'number_of_duplicated_rows': 0,
#      'nans_by_columns': {'Age': 0,
#       'BusinessTravel': 0,
#       'DailyRate': 0,
#       'Department': 0,
#       'DistanceFromHome': 0,
#       'Education': 0,
#       'EducationField': 0,
#       'EnvironmentSatisfaction': 0,
#       'Gender': 0,
#       'HourlyRate': 0,
#       'JobInvolvement': 0,
#       'JobLevel': 0,
#       'JobRole': 0,
#       'JobSatisfaction': 0,
#       'MaritalStatus': 0,
#       'MonthlyIncome': 0,
#       'MonthlyRate': 0,
#       'NumCompaniesWorked': 0,
#       'OverTime': 0,
#       'PercentSalaryHike': 0,
#       'PerformanceRating': 0,
#       'RelationshipSatisfaction': 0,
#       'StockOptionLevel': 0,
#       'TotalWorkingYears': 0,
#       'TrainingTimesLastYear': 0,
#       'WorkLifeBalance': 0,
#       'YearsAtCompany': 0,
#       'YearsInCurrentRole': 0,
#       'YearsSinceLastPromotion': 0,
#       'YearsWithCurrManager': 0},
#      'number_uniques_by_columns': {'Age': 43,
#       'BusinessTravel': 3,
#       'DailyRate': 561,
#       'Department': 3,
#       'DistanceFromHome': 29,
#       'Education': 5,
#       'EducationField': 6,
#       'EnvironmentSatisfaction': 4,
#       'Gender': 2,
#       'HourlyRate': 71,
#       'JobInvolvement': 4,
#       'JobLevel': 5,
#       'JobRole': 9,
#       'JobSatisfaction': 4,
#       'MaritalStatus': 3,
#       'MonthlyIncome': 705,
#       'MonthlyRate': 727,
#       'NumCompaniesWorked': 10,
#       'OverTime': 2,
#       'PercentSalaryHike': 15,
#       'PerformanceRating': 2,
#       'RelationshipSatisfaction': 4,
#       'StockOptionLevel': 4,
#       'TotalWorkingYears': 40,
#       'TrainingTimesLastYear': 7,
#       'WorkLifeBalance': 4,
#       'YearsAtCompany': 34,
#       'YearsInCurrentRole': 18,
#       'YearsSinceLastPromotion': 16,
#       'YearsWithCurrManager': 18}}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'Department',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 3,
#      'unique_percentage': 0.41,
#      'most_common': 'Research & Development',
#      'most_common_percentage': 64.49,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 3,
#      'unique_percentage': 0.41,
#      'most_common': 'Research & Development',
#      'most_common_percentage': 66.26,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'EducationField',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 6,
#      'unique_percentage': 0.82,
#      'most_common': 'Life Sciences',
#      'most_common_percentage': 40.54,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 6,
#      'unique_percentage': 0.82,
#      'most_common': 'Life Sciences',
#      'most_common_percentage': 41.9,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'Gender',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 2,
#      'unique_percentage': 0.27,
#      'most_common': 'Male',
#      'most_common_percentage': 60.14,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 2,
#      'unique_percentage': 0.27,
#      'most_common': 'Male',
#      'most_common_percentage': 59.86,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'JobRole',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 9,
#      'unique_percentage': 1.22,
#      'most_common': 'Sales Executive',
#      'most_common_percentage': 25.03,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 9,
#      'unique_percentage': 1.22,
#      'most_common': 'Research Scientist',
#      'most_common_percentage': 20.27,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'MaritalStatus',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 3,
#      'unique_percentage': 0.41,
#      'most_common': 'Married',
#      'most_common_percentage': 46.12,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 3,
#      'unique_percentage': 0.41,
#      'most_common': 'Married',
#      'most_common_percentage': 45.44,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'OverTime',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 2,
#      'unique_percentage': 0.27,
#      'most_common': 'No',
#      'most_common_percentage': 71.7,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 2,
#      'unique_percentage': 0.27,
#      'most_common': 'No',
#      'most_common_percentage': 71.7,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'Age',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 36.84,
#      'std': 9.31,
#      'min': 18.0,
#      'p25': 30.0,
#      'p50': 35.0,
#      'p75': 43.0,
#      'max': 60.0,
#      'unique': 43,
#      'unique_percentage': 5.85,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 29.0,
#      'most_common_percentage': 5.44},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 37.0,
#      'std': 8.96,
#      'min': 18.0,
#      'p25': 31.0,
#      'p50': 36.0,
#      'p75': 43.0,
#      'max': 59.0,
#      'unique': 42,
#      'unique_percentage': 5.71,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 34.0,
#      'most_common_percentage': 5.71}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'BusinessTravel',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 3,
#      'unique_percentage': 0.41,
#      'most_common': 2,
#      'most_common_percentage': 72.24,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 3,
#      'unique_percentage': 0.41,
#      'most_common': 2,
#      'most_common_percentage': 69.66,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'DailyRate',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 812.43,
#      'std': 400.5,
#      'min': 103.0,
#      'p25': 484.5,
#      'p50': 802.0,
#      'p75': 1168.5,
#      'max': 1499.0,
#      'unique': 561,
#      'unique_percentage': 76.33,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 217.0,
#      'most_common_percentage': 0.54},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 792.54,
#      'std': 406.53,
#      'min': 102.0,
#      'p25': 443.0,
#      'p50': 804.0,
#      'p75': 1146.5,
#      'max': 1495.0,
#      'unique': 556,
#      'unique_percentage': 75.65,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 408.0,
#      'most_common_percentage': 0.68}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'DistanceFromHome',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 9.39,
#      'std': 8.23,
#      'min': 1.0,
#      'p25': 2.0,
#      'p50': 7.0,
#      'p75': 15.0,
#      'max': 29.0,
#      'unique': 29,
#      'unique_percentage': 3.95,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 1.0,
#      'most_common_percentage': 15.51},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 9.0,
#      'std': 7.98,
#      'min': 1.0,
#      'p25': 2.0,
#      'p50': 7.0,
#      'p75': 12.0,
#      'max': 29.0,
#      'unique': 29,
#      'unique_percentage': 3.95,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 15.65}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'Education',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 5,
#      'unique_percentage': 0.68,
#      'most_common': 3,
#      'most_common_percentage': 37.69,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 5,
#      'unique_percentage': 0.68,
#      'most_common': 3,
#      'most_common_percentage': 40.14,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'EnvironmentSatisfaction',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 30.75,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 4,
#      'most_common_percentage': 31.56,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'HourlyRate',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 64.69,
#      'std': 20.14,
#      'min': 30.0,
#      'p25': 47.0,
#      'p50': 65.0,
#      'p75': 82.0,
#      'max': 100.0,
#      'unique': 71,
#      'unique_percentage': 9.66,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 43.0,
#      'most_common_percentage': 2.18},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 67.1,
#      'std': 20.46,
#      'min': 30.0,
#      'p25': 49.0,
#      'p50': 67.0,
#      'p75': 84.5,
#      'max': 100.0,
#      'unique': 71,
#      'unique_percentage': 9.66,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 84.0,
#      'most_common_percentage': 2.72}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'JobInvolvement',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 59.73,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 58.37,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'JobLevel',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 5,
#      'unique_percentage': 0.68,
#      'most_common': 2,
#      'most_common_percentage': 38.78,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 5,
#      'unique_percentage': 0.68,
#      'most_common': 1,
#      'most_common_percentage': 38.91,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'JobSatisfaction',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 30.34,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 4,
#      'most_common_percentage': 33.61,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'MonthlyIncome',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 6469.34,
#      'std': 4564.06,
#      'min': 1009.0,
#      'p25': 3039.5,
#      'p50': 5021.0,
#      'p75': 8154.5,
#      'max': 19973.0,
#      'unique': 705,
#      'unique_percentage': 95.92,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2559.0,
#      'most_common_percentage': 0.27},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 6536.52,
#      'std': 4850.46,
#      'min': 1052.0,
#      'p25': 2855.5,
#      'p50': 4759.0,
#      'p75': 8620.5,
#      'max': 19999.0,
#      'unique': 706,
#      'unique_percentage': 96.05,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2657.0,
#      'most_common_percentage': 0.27}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'MonthlyRate',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 14419.18,
#      'std': 7163.14,
#      'min': 2125.0,
#      'p25': 8056.0,
#      'p50': 14561.0,
#      'p75': 20911.5,
#      'max': 26999.0,
#      'unique': 727,
#      'unique_percentage': 98.91,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 4658.0,
#      'most_common_percentage': 0.27},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 14207.03,
#      'std': 7075.43,
#      'min': 2094.0,
#      'p25': 8029.0,
#      'p50': 14039.0,
#      'p75': 20272.0,
#      'max': 26997.0,
#      'unique': 722,
#      'unique_percentage': 98.23,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 9150.0,
#      'most_common_percentage': 0.41}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'NumCompaniesWorked',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 2.68,
#      'std': 2.49,
#      'min': 0.0,
#      'p25': 1.0,
#      'p50': 2.0,
#      'p75': 4.0,
#      'max': 9.0,
#      'unique': 10,
#      'unique_percentage': 1.36,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 1.0,
#      'most_common_percentage': 34.42},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 2.7,
#      'std': 2.51,
#      'min': 0.0,
#      'p25': 1.0,
#      'p50': 2.0,
#      'p75': 4.0,
#      'max': 9.0,
#      'unique': 10,
#      'unique_percentage': 1.36,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 1.0,
#      'most_common_percentage': 36.46}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'PercentSalaryHike',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 15.12,
#      'std': 3.6,
#      'min': 11.0,
#      'p25': 12.0,
#      'p50': 14.0,
#      'p75': 17.0,
#      'max': 25.0,
#      'unique': 15,
#      'unique_percentage': 2.04,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 12.0,
#      'most_common_percentage': 15.1},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 15.3,
#      'std': 3.72,
#      'min': 11.0,
#      'p25': 12.0,
#      'p50': 14.0,
#      'p75': 18.0,
#      'max': 25.0,
#      'unique': 15,
#      'unique_percentage': 2.04,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 11.0,
#      'most_common_percentage': 15.1}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'PerformanceRating',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 2,
#      'unique_percentage': 0.27,
#      'most_common': 3,
#      'most_common_percentage': 85.58,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 2,
#      'unique_percentage': 0.27,
#      'most_common': 3,
#      'most_common_percentage': 83.67,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'RelationshipSatisfaction',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 4,
#      'most_common_percentage': 31.97,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 32.79,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'StockOptionLevel',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 0,
#      'most_common_percentage': 42.45,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 0,
#      'most_common_percentage': 43.4,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'TotalWorkingYears',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 11.23,
#      'std': 7.71,
#      'min': 0.0,
#      'p25': 6.0,
#      'p50': 10.0,
#      'p75': 15.0,
#      'max': 40.0,
#      'unique': 40,
#      'unique_percentage': 5.44,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 10.0,
#      'most_common_percentage': 14.01},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 11.33,
#      'std': 7.85,
#      'min': 0.0,
#      'p25': 6.0,
#      'p50': 10.0,
#      'p75': 15.0,
#      'max': 40.0,
#      'unique': 39,
#      'unique_percentage': 5.31,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 10.0,
#      'most_common_percentage': 13.47}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'TrainingTimesLastYear',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 2.77,
#      'std': 1.25,
#      'min': 0.0,
#      'p25': 2.0,
#      'p50': 3.0,
#      'p75': 3.0,
#      'max': 6.0,
#      'unique': 7,
#      'unique_percentage': 0.95,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 38.64},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 2.83,
#      'std': 1.33,
#      'min': 0.0,
#      'p25': 2.0,
#      'p50': 3.0,
#      'p75': 3.0,
#      'max': 6.0,
#      'unique': 7,
#      'unique_percentage': 0.95,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 35.78}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'WorkLifeBalance',
#     'column_type': 'cat',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 60.0,
#      'new_in_current_values_count': None,
#      'unused_in_current_values_count': None},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'unique': 4,
#      'unique_percentage': 0.54,
#      'most_common': 3,
#      'most_common_percentage': 61.5,
#      'new_in_current_values_count': 0,
#      'unused_in_current_values_count': 0}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'YearsAtCompany',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 6.8,
#      'std': 5.8,
#      'min': 0.0,
#      'p25': 3.0,
#      'p50': 5.0,
#      'p75': 9.0,
#      'max': 37.0,
#      'unique': 34,
#      'unique_percentage': 4.63,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 5.0,
#      'most_common_percentage': 14.97},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 7.21,
#      'std': 6.43,
#      'min': 0.0,
#      'p25': 3.0,
#      'p50': 5.0,
#      'p75': 9.5,
#      'max': 40.0,
#      'unique': 34,
#      'unique_percentage': 4.63,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 1.0,
#      'most_common_percentage': 12.65}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'YearsInCurrentRole',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 4.18,
#      'std': 3.52,
#      'min': 0.0,
#      'p25': 2.0,
#      'p50': 3.0,
#      'p75': 7.0,
#      'max': 17.0,
#      'unique': 18,
#      'unique_percentage': 2.45,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 25.71},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 4.27,
#      'std': 3.72,
#      'min': 0.0,
#      'p25': 2.0,
#      'p50': 3.0,
#      'p75': 7.0,
#      'max': 18.0,
#      'unique': 19,
#      'unique_percentage': 2.59,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 24.9}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'YearsSinceLastPromotion',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 2.16,
#      'std': 3.1,
#      'min': 0.0,
#      'p25': 0.0,
#      'p50': 1.0,
#      'p75': 3.0,
#      'max': 15.0,
#      'unique': 16,
#      'unique_percentage': 2.18,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 0.0,
#      'most_common_percentage': 38.23},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 2.22,
#      'std': 3.34,
#      'min': 0.0,
#      'p25': 0.0,
#      'p50': 1.0,
#      'p75': 3.0,
#      'max': 15.0,
#      'unique': 16,
#      'unique_percentage': 2.18,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 0.0,
#      'most_common_percentage': 40.82}}},
#   {'metric': 'ColumnSummaryMetric',
#    'result': {'column_name': 'YearsWithCurrManager',
#     'column_type': 'num',
#     'reference_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 4.06,
#      'std': 3.44,
#      'min': 0.0,
#      'p25': 2.0,
#      'p50': 3.0,
#      'p75': 7.0,
#      'max': 17.0,
#      'unique': 18,
#      'unique_percentage': 2.45,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 25.17},
#     'current_characteristics': {'number_of_rows': 735,
#      'count': 735,
#      'missing': 0,
#      'missing_percentage': 0.0,
#      'mean': 4.18,
#      'std': 3.69,
#      'min': 0.0,
#      'p25': 2.0,
#      'p50': 3.0,
#      'p75': 7.0,
#      'max': 17.0,
#      'unique': 18,
#      'unique_percentage': 2.45,
#      'infinite_count': 0,
#      'infinite_percentage': 0.0,
#      'most_common': 2.0,
#      'most_common_percentage': 21.63}}},
#   {'metric': 'DatasetMissingValuesMetric',
#    'result': {'current': {'different_missing_values': {'': 0,
#       -inf: 0,
#       None: 0,
#       inf: 0},
#      'number_of_different_missing_values': 0,
#      'different_missing_values_by_column': {'Age': {'': 0,
#        -inf: 0,
#        None: 0,
#        inf: 0},
#       'BusinessTravel': {'': 0, -inf: 0, None: 0, inf: 0},
#       'DailyRate': {'': 0, -inf: 0, None: 0, inf: 0},
#       'Department': {'': 0, -inf: 0, None: 0, inf: 0},
#       'DistanceFromHome': {'': 0, -inf: 0, None: 0, inf: 0},
#       'Education': {'': 0, -inf: 0, None: 0, inf: 0},
#       'EducationField': {'': 0, -inf: 0, None: 0, inf: 0},
#       'EnvironmentSatisfaction': {'': 0, -inf: 0, None: 0, inf: 0},
#       'Gender': {'': 0, -inf: 0, None: 0, inf: 0},
#       'HourlyRate': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobInvolvement': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobLevel': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobRole': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobSatisfaction': {'': 0, -inf: 0, None: 0, inf: 0},
#       'MaritalStatus': {'': 0, -inf: 0, None: 0, inf: 0},
#       'MonthlyIncome': {'': 0, -inf: 0, None: 0, inf: 0},
#       'MonthlyRate': {'': 0, -inf: 0, None: 0, inf: 0},
#       'NumCompaniesWorked': {'': 0, -inf: 0, None: 0, inf: 0},
#       'OverTime': {'': 0, -inf: 0, None: 0, inf: 0},
#       'PercentSalaryHike': {'': 0, -inf: 0, None: 0, inf: 0},
#       'PerformanceRating': {'': 0, -inf: 0, None: 0, inf: 0},
#       'RelationshipSatisfaction': {'': 0, -inf: 0, None: 0, inf: 0},
#       'StockOptionLevel': {'': 0, -inf: 0, None: 0, inf: 0},
#       'TotalWorkingYears': {'': 0, -inf: 0, None: 0, inf: 0},
#       'TrainingTimesLastYear': {'': 0, -inf: 0, None: 0, inf: 0},
#       'WorkLifeBalance': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsAtCompany': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsInCurrentRole': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsSinceLastPromotion': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsWithCurrManager': {'': 0, -inf: 0, None: 0, inf: 0}},
#      'number_of_different_missing_values_by_column': {'Age': 0,
#       'BusinessTravel': 0,
#       'DailyRate': 0,
#       'Department': 0,
#       'DistanceFromHome': 0,
#       'Education': 0,
#       'EducationField': 0,
#       'EnvironmentSatisfaction': 0,
#       'Gender': 0,
#       'HourlyRate': 0,
#       'JobInvolvement': 0,
#       'JobLevel': 0,
#       'JobRole': 0,
#       'JobSatisfaction': 0,
#       'MaritalStatus': 0,
#       'MonthlyIncome': 0,
#       'MonthlyRate': 0,
#       'NumCompaniesWorked': 0,
#       'OverTime': 0,
#       'PercentSalaryHike': 0,
#       'PerformanceRating': 0,
#       'RelationshipSatisfaction': 0,
#       'StockOptionLevel': 0,
#       'TotalWorkingYears': 0,
#       'TrainingTimesLastYear': 0,
#       'WorkLifeBalance': 0,
#       'YearsAtCompany': 0,
#       'YearsInCurrentRole': 0,
#       'YearsSinceLastPromotion': 0,
#       'YearsWithCurrManager': 0},
#      'number_of_missing_values': 0,
#      'share_of_missing_values': 0.0,
#      'number_of_missing_values_by_column': {'Age': 0,
#       'BusinessTravel': 0,
#       'DailyRate': 0,
#       'Department': 0,
#       'DistanceFromHome': 0,
#       'Education': 0,
#       'EducationField': 0,
#       'EnvironmentSatisfaction': 0,
#       'Gender': 0,
#       'HourlyRate': 0,
#       'JobInvolvement': 0,
#       'JobLevel': 0,
#       'JobRole': 0,
#       'JobSatisfaction': 0,
#       'MaritalStatus': 0,
#       'MonthlyIncome': 0,
#       'MonthlyRate': 0,
#       'NumCompaniesWorked': 0,
#       'OverTime': 0,
#       'PercentSalaryHike': 0,
#       'PerformanceRating': 0,
#       'RelationshipSatisfaction': 0,
#       'StockOptionLevel': 0,
#       'TotalWorkingYears': 0,
#       'TrainingTimesLastYear': 0,
#       'WorkLifeBalance': 0,
#       'YearsAtCompany': 0,
#       'YearsInCurrentRole': 0,
#       'YearsSinceLastPromotion': 0,
#       'YearsWithCurrManager': 0},
#      'share_of_missing_values_by_column': {'Age': 0.0,
#       'BusinessTravel': 0.0,
#       'DailyRate': 0.0,
#       'Department': 0.0,
#       'DistanceFromHome': 0.0,
#       'Education': 0.0,
#       'EducationField': 0.0,
#       'EnvironmentSatisfaction': 0.0,
#       'Gender': 0.0,
#       'HourlyRate': 0.0,
#       'JobInvolvement': 0.0,
#       'JobLevel': 0.0,
#       'JobRole': 0.0,
#       'JobSatisfaction': 0.0,
#       'MaritalStatus': 0.0,
#       'MonthlyIncome': 0.0,
#       'MonthlyRate': 0.0,
#       'NumCompaniesWorked': 0.0,
#       'OverTime': 0.0,
#       'PercentSalaryHike': 0.0,
#       'PerformanceRating': 0.0,
#       'RelationshipSatisfaction': 0.0,
#       'StockOptionLevel': 0.0,
#       'TotalWorkingYears': 0.0,
#       'TrainingTimesLastYear': 0.0,
#       'WorkLifeBalance': 0.0,
#       'YearsAtCompany': 0.0,
#       'YearsInCurrentRole': 0.0,
#       'YearsSinceLastPromotion': 0.0,
#       'YearsWithCurrManager': 0.0},
#      'number_of_rows': 735,
#      'number_of_rows_with_missing_values': 0,
#      'share_of_rows_with_missing_values': 0.0,
#      'number_of_columns': 30,
#      'columns_with_missing_values': [],
#      'number_of_columns_with_missing_values': 0,
#      'share_of_columns_with_missing_values': 0.0},
#     'reference': {'different_missing_values': {'': 0,
#       -inf: 0,
#       None: 0,
#       inf: 0},
#      'number_of_different_missing_values': 0,
#      'different_missing_values_by_column': {'Age': {'': 0,
#        -inf: 0,
#        None: 0,
#        inf: 0},
#       'BusinessTravel': {'': 0, -inf: 0, None: 0, inf: 0},
#       'DailyRate': {'': 0, -inf: 0, None: 0, inf: 0},
#       'Department': {'': 0, -inf: 0, None: 0, inf: 0},
#       'DistanceFromHome': {'': 0, -inf: 0, None: 0, inf: 0},
#       'Education': {'': 0, -inf: 0, None: 0, inf: 0},
#       'EducationField': {'': 0, -inf: 0, None: 0, inf: 0},
#       'EnvironmentSatisfaction': {'': 0, -inf: 0, None: 0, inf: 0},
#       'Gender': {'': 0, -inf: 0, None: 0, inf: 0},
#       'HourlyRate': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobInvolvement': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobLevel': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobRole': {'': 0, -inf: 0, None: 0, inf: 0},
#       'JobSatisfaction': {'': 0, -inf: 0, None: 0, inf: 0},
#       'MaritalStatus': {'': 0, -inf: 0, None: 0, inf: 0},
#       'MonthlyIncome': {'': 0, -inf: 0, None: 0, inf: 0},
#       'MonthlyRate': {'': 0, -inf: 0, None: 0, inf: 0},
#       'NumCompaniesWorked': {'': 0, -inf: 0, None: 0, inf: 0},
#       'OverTime': {'': 0, -inf: 0, None: 0, inf: 0},
#       'PercentSalaryHike': {'': 0, -inf: 0, None: 0, inf: 0},
#       'PerformanceRating': {'': 0, -inf: 0, None: 0, inf: 0},
#       'RelationshipSatisfaction': {'': 0, -inf: 0, None: 0, inf: 0},
#       'StockOptionLevel': {'': 0, -inf: 0, None: 0, inf: 0},
#       'TotalWorkingYears': {'': 0, -inf: 0, None: 0, inf: 0},
#       'TrainingTimesLastYear': {'': 0, -inf: 0, None: 0, inf: 0},
#       'WorkLifeBalance': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsAtCompany': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsInCurrentRole': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsSinceLastPromotion': {'': 0, -inf: 0, None: 0, inf: 0},
#       'YearsWithCurrManager': {'': 0, -inf: 0, None: 0, inf: 0}},
#      'number_of_different_missing_values_by_column': {'Age': 0,
#       'BusinessTravel': 0,
#       'DailyRate': 0,
#       'Department': 0,
#       'DistanceFromHome': 0,
#       'Education': 0,
#       'EducationField': 0,
#       'EnvironmentSatisfaction': 0,
#       'Gender': 0,
#       'HourlyRate': 0,
#       'JobInvolvement': 0,
#       'JobLevel': 0,
#       'JobRole': 0,
#       'JobSatisfaction': 0,
#       'MaritalStatus': 0,
#       'MonthlyIncome': 0,
#       'MonthlyRate': 0,
#       'NumCompaniesWorked': 0,
#       'OverTime': 0,
#       'PercentSalaryHike': 0,
#       'PerformanceRating': 0,
#       'RelationshipSatisfaction': 0,
#       'StockOptionLevel': 0,
#       'TotalWorkingYears': 0,
#       'TrainingTimesLastYear': 0,
#       'WorkLifeBalance': 0,
#       'YearsAtCompany': 0,
#       'YearsInCurrentRole': 0,
#       'YearsSinceLastPromotion': 0,
#       'YearsWithCurrManager': 0},
#      'number_of_missing_values': 0,
#      'share_of_missing_values': 0.0,
#      'number_of_missing_values_by_column': {'Age': 0,
#       'BusinessTravel': 0,
#       'DailyRate': 0,
#       'Department': 0,
#       'DistanceFromHome': 0,
#       'Education': 0,
#       'EducationField': 0,
#       'EnvironmentSatisfaction': 0,
#       'Gender': 0,
#       'HourlyRate': 0,
#       'JobInvolvement': 0,
#       'JobLevel': 0,
#       'JobRole': 0,
#       'JobSatisfaction': 0,
#       'MaritalStatus': 0,
#       'MonthlyIncome': 0,
#       'MonthlyRate': 0,
#       'NumCompaniesWorked': 0,
#       'OverTime': 0,
#       'PercentSalaryHike': 0,
#       'PerformanceRating': 0,
#       'RelationshipSatisfaction': 0,
#       'StockOptionLevel': 0,
#       'TotalWorkingYears': 0,
#       'TrainingTimesLastYear': 0,
#       'WorkLifeBalance': 0,
#       'YearsAtCompany': 0,
#       'YearsInCurrentRole': 0,
#       'YearsSinceLastPromotion': 0,
#       'YearsWithCurrManager': 0},
#      'share_of_missing_values_by_column': {'Age': 0.0,
#       'BusinessTravel': 0.0,
#       'DailyRate': 0.0,
#       'Department': 0.0,
#       'DistanceFromHome': 0.0,
#       'Education': 0.0,
#       'EducationField': 0.0,
#       'EnvironmentSatisfaction': 0.0,
#       'Gender': 0.0,
#       'HourlyRate': 0.0,
#       'JobInvolvement': 0.0,
#       'JobLevel': 0.0,
#       'JobRole': 0.0,
#       'JobSatisfaction': 0.0,
#       'MaritalStatus': 0.0,
#       'MonthlyIncome': 0.0,
#       'MonthlyRate': 0.0,
#       'NumCompaniesWorked': 0.0,
#       'OverTime': 0.0,
#       'PercentSalaryHike': 0.0,
#       'PerformanceRating': 0.0,
#       'RelationshipSatisfaction': 0.0,
#       'StockOptionLevel': 0.0,
#       'TotalWorkingYears': 0.0,
#       'TrainingTimesLastYear': 0.0,
#       'WorkLifeBalance': 0.0,
#       'YearsAtCompany': 0.0,
#       'YearsInCurrentRole': 0.0,
#       'YearsSinceLastPromotion': 0.0,
#       'YearsWithCurrManager': 0.0},
#      'number_of_rows': 735,
#      'number_of_rows_with_missing_values': 0,
#      'share_of_rows_with_missing_values': 0.0,
#      'number_of_columns': 30,
#      'columns_with_missing_values': [],
#      'number_of_columns_with_missing_values': 0,
#      'share_of_columns_with_missing_values': 0.0}}},
#   {'metric': 'DatasetCorrelationsMetric',
#    'result': {'current': {'stats': {'pearson': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.7740995825208886,
#        'abs_max_features_correlation': 0.7740995825208886},
#       'spearman': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.8555955059987685,
#        'abs_max_features_correlation': 0.8555955059987685},
#       'kendall': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.7478399529736042,
#        'abs_max_features_correlation': 0.7478399529736042},
#       'cramer_v': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.9306699009782146,
#        'abs_max_features_correlation': 0.9306699009782146}}},
#     'reference': {'stats': {'pearson': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.7753870045852559,
#        'abs_max_features_correlation': 0.7753870045852559},
#       'spearman': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.8520654933822873,
#        'abs_max_features_correlation': 0.8520654933822873},
#       'kendall': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.7554018323314996,
#        'abs_max_features_correlation': 0.7554018323314996},
#       'cramer_v': {'target_prediction_correlation': None,
#        'abs_max_target_features_correlation': None,
#        'abs_max_prediction_features_correlation': None,
#        'abs_max_correlation': 0.952696225694677,
#        'abs_max_features_correlation': 0.952696225694677}}}}}]}

# %%
# We can also obtain a visual report for data quality as a html file
# this html file can be found in the html_reports folder, with the name:
# data_quality_report.html
data_quality_report = model_monitoring.data_quality_report(train_df.drop(columns=['target', 'prediction']),
                                     test_df.drop(columns=['target', 'prediction']),
                                     'html')
data_quality_report
# Out:
# <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons"/>
# <style>
# .reset-this-parent {
#   all: initial;
# }
# .reset-this-parent h5 {
#   all: initial;
#   font: initial;
# }
#
# svg {
#   height: intrinsic !important;
# }
# </style>
# <script>
#     var evidently_dashboard_deffb0103135466488b54030fe25f017 = {"name": "Report", "widgets": [{"type": "counter", "title": "", "size": 2, "id": "c8c00e05-16e5-4b9b-b1ff-ccadb11ff27d", "details": "", "alertsPosition": null, "alertStats": null, "params": {"counters": [{"value": "", "label": "Dataset Summary"}]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "table", "title": "", "size": 2, "id": "41649974-0ae3-4e5d-acee-81f715bce85d", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": ["Metric", "Current", "Reference"], "data": [["id column", "None", "None"], ["target column", "None", "None"], ["prediction column", "None", "None"], ["date column", "None", "None"], ["number of columns", "30", "30"], ["number of rows", "735", "735"], ["missing values", "0", "0"], ["categorical columns", "6", "6"], ["numeric columns", "24", "24"], ["text columns", "0", "0"], ["datetime columns", "0", "0"], ["empty columns", "0", "0"], ["constant columns", "0", "0"], ["almost constant features", "0", "0"], ["duplicated columns", "0", "0"], ["almost duplicated features", "0", "0"]]}, "insights": [], "alerts": [], "tabs": [], "widgets": [], "pageSize": 5}, {"type": "rich_data", "title": "", "size": 2, "id": "f7dd1e97-d562-4ff8-8b90-820e31edc6f9", "details": "", "alertsPosition": null, "alertStats": null, "params": {"header": "Department", "description": "cat", "metricsValuesHeaders": ["current", "reference"], "metrics": [{"label": "count", "values": ["735", "735"]}, {"label": "unique", "values": ["3 (0.41%)", "3 (0.41%)"]}, {"label": "most common", "values": ["Research & Development (66.26%)", "Research & Development (64.49%)"]}, {"label": "missing", "values": ["0 (0.0%)", "0 (0.0%)"]}, {"label": "new categories", "values": ["0", ""]}, {"label": "missing categories", "values": ["0", ""]}], "graph": {"data": [{"marker": {"color": "#ed0400"}, "name": "current", "orientation": "v", "x": ["Research & Development", "Sales", "Human Resources"], "y": [487, 209, 39], "type": "bar"}, {"marker": {"color": "#4d4d4d"}, "name": "reference", "orientation": "v", "x": ["Research & Development", "Sales", "Human Resources"], "y": [474, 237, 24], "type": "bar"}], "layout": {"template": {"data": {"histogram2dcontour": [{"type": "histogram2dcontour", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "choropleth": [{"type": "choropleth", "colorbar": {"outlinewidth": 0, "ticks": ""}}], "histogram2d": [{"type": "histogram2d", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmap": [{"type": "heatmap", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "heatmapgl": [{"type": "heatmapgl", "colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]]}], "contourcarpet": [{"type": "contourcarpe ...

# %% [markdown]
# Based on this data_quality_dict, we can obtain some information about the incoming data.
# Such as:
# the number of duplicated columns, the number of duplcated rows,
# the number of empty rows, the number of empty columns and
# the number of NaNs in each columns
#
# So we can use the values obtained from this dictionary as an indicator such that only when these numbers are more than zero than we shall do something about them
#
# The next few functions will make use of this dictionary

# %%
# we handle the missing values of test_df first
test_df = model_monitoring.handle_missing_values(data_quality_dict, 'delete', test_df)

# %%
# then once we've finished preparing the incoming dataset for preprocessing, we let it go through the preprocessing pipeline
# after going through the preprocessing pipeline, need to check whether the validity of the preprocessing
X_train_processed = pd.read_csv("../data/X_train_processed.csv")
X_test_processed = pd.read_csv("../data/X_test_processed.csv")
model_monitoring.check_schema_postprocessing(X_train_processed, X_test_processed)
# Out:
# train and test dataset have the same processed features
# 1
